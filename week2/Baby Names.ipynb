# %% [markdown]
# # US Baby Names 1880-2010

# %% [markdown]
# The baby names datasets are contained in the acompanying folder ./names (or [download here](http://www.ssa.gov/oact/babynames/limits.html)) they contain a list of the most frequent names given to newborn babies in the United States each year.
# There are many things you might want to do with the dataset:
#
# * Visualize the proportion of babies given a particular name (your own, or another name) over time.
# * Determine the relative rank of a name.
# * Determine the most popular names in each year or the names with largest increases or decreases.
# * Analyze trends in names: vowels, consonants, length, overall diversity, changes in spelling, first and last letters.
# * Analyze external sources of trends: biblical names, celebrities, demographic changes.
#
# In this exercise you are tasked with undertaking some analysis. I have started some of the steps for you and I have given some tips on what methods to use.

# %% [markdown]
# ## Task 1: Import Data

# %% [markdown]
# As with most analysis we will need to import some libraries. For this analyis we want to reading the data, perform analysis and visualise the data. therefore the Pandas and matplotlib libraries are needed.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# First open a single file 1880 set the field headings to'name', 'sex', 'births' (hint use the pandas read_csv method)

# %%
from pandas import read_csv
filename='names/yob1880.txt'
names=['name', 'sex', 'births']
data=read_csv(filename, names=names)
print(data)
# Out:
#            name sex  births
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# ...         ...  ..     ...
# 1995     Woodie   M       5
# 1996     Worthy   M       5
# 1997     Wright   M       5
# 1998       York   M       5
# 1999  Zachariah   M       5
#
# [2000 rows x 3 columns]

# %%
from pandas import read_csv
filename='names/yob1880.txt'
columns=['name', 'sex', 'births']
data=read_csv(filename, names=columns, usecols=["name"], engine='python')
print(data)
# Out:
#            name
# 0          Mary
# 1          Anna
# 2          Emma
# 3     Elizabeth
# 4        Minnie
# ...         ...
# 1995     Woodie
# 1996     Worthy
# 1997     Wright
# 1998       York
# 1999  Zachariah
#
# [2000 rows x 1 columns]

# %% [markdown]
# Now display the top 5 rows

# %%
data.head(5)
# Out:
#         name sex  births
# 0       Mary   F    7065
# 1       Anna   F    2604
# 2       Emma   F    2003
# 3  Elizabeth   F    1939
# 4     Minnie   F    1746

# %% [markdown]
# Often datasets span more than one file.
#
# In this example each year is in a seperate file, we need to combines all of this year data into a single pandas DataFrame and add a *year* field. Note that all .txt files must be stored as *./names*.
#
# This is a little challenging so I have completed this task below, make sure you understand how the code below operates.

# %% [markdown]
# Now display the first 5 records from the combined dataframe

# %%
names.head(5)
# Out:
#   sex  births  year
# 0   F    7065  1880
# 1   F    2604  1880
# 2   F    2003  1880
# 3   F    1939  1880
# 4   F    1746  1880

# %% [markdown]
# ## Task 2: Descriptive Statistics
#
# Descriptive statistics can give you great insight into the properties of each attribute. Often you can create more summaries than you have time to review.
#
# Display the following summary statistics.
#
#     Count.
#     Mean.
#     Standard Deviation.
#     Minimum Value.
#     25th Percentile.
#     50th Percentile (Median). 75th Percentile.
#     Maximum Value.

# %%
# Statistical Summary
from pandas import set_option
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.width', 100)
names.births.describe()
# Out:
# count   1759622.00
# mean        187.48
# std        1590.41
# min           5.00
# 25%           7.00
# 50%          12.00
# 75%          32.00
# max       99686.00
# Name: births, dtype: float64

# %% [markdown]
# ## Task 3: Data Aggregation

# %% [markdown]
# We can now perform several types of aggregation.
#
# Create a new DataFrame containing the total number of births per year, split by sex.
#
# (Hint use the pivot_table method with the aggragate function sum property)

# %%
# print(names)
groupByYear = names.groupby('year').size
print(groupByYear)
numberOfBirthsBySex = pd.pivot_table(names, values='births', index='year', columns='sex', aggfunc=sum)
print(numberOfBirthsBySex)
# Out:
# <bound method GroupBy.size of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000002386BB39900>>
# sex         F        M
# year
# 1880    90993   110491
# 1881    91953   100743
# 1882   107847   113686
# 1883   112319   104627
# 1884   129020   114442
# ...       ...      ...
# 2008  1888607  2037751
# 2009  1834599  1981039
# 2010  1774758  1915942
# 2011  1756004  1895910
# 2012  1757328  1893134
#
# [133 rows x 2 columns]

# %% [markdown]
# Now display the first 5 records from the combined dataframe. Hint you can use the head() method.

# %%
numberOfBirthsBySex.head(5)
# Out:
# sex        F       M
# year
# 1880   90993  110491
# 1881   91953  100743
# 1882  107847  113686
# 1883  112319  104627
# 1884  129020  114442

# %% [markdown]
# ## Task 4: Data Visualisation

# %% [markdown]
# Using the *plot* function draw a figure to illustrate this DataFrame.
#
# Plot the genders in 2 seperate lines with year on the X axis and the number of births on the Y axis, Don't forget a title and axis labels.

# %%
print(names)
names.plot.hist(by='year', column='births')
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# ...            ...  ..     ...   ...
# 1759617      Zylin   M       5  2012
# 1759618     Zymari   M       5  2012
# 1759619      Zyrin   M       5  2012
# 1759620      Zyrus   M       5  2012
# 1759621  Zytaevius   M       5  2012
#
# [1759622 rows x 4 columns]
# array([<AxesSubplot: title={'center': '1880'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1881'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1882'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1883'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1884'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1885'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1886'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1887'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1888'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1889'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1890'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1891'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1892'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1893'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1894'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1895'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1896'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1897'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1898'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1899'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1900'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1901'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1902'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1903'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1904'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1905'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1906'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1907'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1908'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1909'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1910'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1911'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1912'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1913'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1914'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1915'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1916'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1917'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1918'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1919'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1920'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1921'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1922'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1923'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1924'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1925'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1926'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1927'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1928'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1929'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1930'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1931'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1932'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1933'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1934'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1935'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1936'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1937'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1938'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1939'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1940'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1941'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1942'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1943'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1944'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1945'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1946'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1947'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1948'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1949'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1950'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1951'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1952'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1953'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1954'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1955'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1956'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1957'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1958'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1959'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1960'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1961'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1962'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1963'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1964'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1965'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1966'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1967'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1968'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1969'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1970'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1971'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1972'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1973'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1974'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1975'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1976'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1977'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1978'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1979'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1980'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1981'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1982'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1983'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1984'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1985'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1986'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1987'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1988'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1989'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1990'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1991'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1992'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1993'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1994'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1995'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1996'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1997'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1998'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '1999'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2000'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2001'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2002'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2003'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2004'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2005'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2006'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2007'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2008'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2009'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2010'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2011'}, ylabel='Frequency'>,
#        <AxesSubplot: title={'center': '2012'}, ylabel='Frequency'>],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
year=names.year
births=names.births
sex=names.sex
plt.title('Birth by year')
plt.plot(year, births)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
year=names.year
births=names.births

# plot
fig, ax = plt.subplots()

ax.plot(year, births, linewidth=2.0)

plt.show()

# %%
numberOfBirthsBySex.plot(figsize=(20,10), title='Births by year')
# Out:
# <AxesSubplot: title={'center': 'Births by year'}, xlabel='year'>

# %% [markdown]
# ## Task 5: More Data Aggregation

# %% [markdown]
# Now we would like to analyse how frequently the names *John*, *Michael*, *Mary*, *Mark*,*Jeremy* and *Amelia* occurr over time.

# %% [markdown]
# Redefine *total_births*, this time aggregating data by *name* rather than *sex*.
#
# Then define the subset of names that we are interested
#
# Finally plot each name in its own graph.

# %%
birthsTotal = names.pivot_table('births', 'year', 'name', aggfunc=sum)
subset = birthsTotal[['John', 'Michael', 'Mary', 'Mark','Jeremy','Amelia']]
subset.plot(subplots=True, figsize=(20, 20), title="Popular Names")
# Out:
# array([<AxesSubplot: xlabel='year'>, <AxesSubplot: xlabel='year'>,
#        <AxesSubplot: xlabel='year'>, <AxesSubplot: xlabel='year'>,
#        <AxesSubplot: xlabel='year'>, <AxesSubplot: xlabel='year'>],
#       dtype=object)

# %% [markdown]
# ## Task 6: Data Distrabution

# %% [markdown]
# Next we need to look at how the distribution of boy names by final letter has changed over the last 100 years.
#
# To see this, first aggregate all of the births in the full dataset by year, sex, and final letter.
#
# (This is a bit tricky so I have done some of the difficult bits)

# %%
# extract last letter from name column
get_last_letter = lambda x: x[-1]
last_letters = names.name.map(get_last_letter)
last_letters.name = 'last_letter'
table = names.pivot_table('births',last_letters,['sex', 'year'], aggfunc=sum)

# %% [markdown]
# Then we select a few representative years 1912, 1962, 2012, spanning 100 years in total, display the first 5 records in a table:
#
# (Hint: use the reindex method https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reindex.html)

# %%
span = table.reindex(columns=[1912, 1962, 2012], level='year')
span.head(5)
# Out:
# sex                 F                            M
# year             1912      1962      2012     1912      1962      2012
# last_letter
# a           149178.00 682541.00 654517.00  1655.00   5331.00  27201.00
# b                 NaN    459.00    471.00   923.00   3458.00  34706.00
# c                 NaN     73.00   1235.00  1053.00  17881.00  24268.00
# d            10523.00   3673.00   2530.00 54090.00 249996.00  42457.00
# e           180522.00 424745.00 320528.00 54716.00 164952.00 128430.00

# %% [markdown]
# Now, we normalize the table by the number of births, so as to obtain the proportion of total births for each sex ending in each letter:
#
# There are functions in python for normalisation but we haven't covered them yet. Here we will just simply divide each value by the aggragated sum for that table. i.e. divide each subtable by the total

# %%
letter_prop = span/span.sum().astype(float)
letter_prop.head()
# Out:
# sex            F              M
# year        1912 1962 2012 1912 1962 2012
# last_letter
# a           0.27 0.35 0.37 0.00 0.00 0.01
# b            NaN 0.00 0.00 0.00 0.00 0.02
# c            NaN 0.00 0.00 0.00 0.01 0.01
# d           0.02 0.00 0.00 0.13 0.12 0.02
# e           0.32 0.22 0.18 0.13 0.08 0.07

# %% [markdown]
# Finally make <b>bar plots</b> for each sex broken-down by year

# %%
fig, axes = plt.subplots(2, 1, figsize=(11, 10))
letter_prop['M'].plot(kind='bar', rot=0, ax=axes[0], title='Male')
letter_prop['F'].plot(kind='bar', rot=0, ax=axes[1], title='Female',legend=False)
# Out:
# <AxesSubplot: title={'center': 'Female'}, xlabel='last_letter'>
